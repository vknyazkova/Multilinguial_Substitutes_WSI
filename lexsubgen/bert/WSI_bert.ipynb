# %% [markdown]
# # Подключение гугл диска

# %%
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/3_year/WSI
# Out:
# /content/gdrive/MyDrive/3_year/WSI

# %% [markdown]
# # Установки и импорты

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deep-translator (from -r requirements.txt (line 1))
#   Downloading deep_translator-1.11.1-py3-none-any.whl (37 kB)
# Collecting fasttext-wheel (from -r requirements.txt (line 2))
#   Downloading fasttext_wheel-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.6 MB/s eta 0:00:00
# Collecting fuzzywuzzy[speedup] (from -r requirements.txt (line 3))
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (4.65.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (2.0.1+cu118)
# Collecting transformers (from -r requirements.txt (line 10))
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 58.0 MB/s eta 0:00:00
# Collecting simalign (from -r requirements.txt (line 11))
#   Downloading simalign-0.3-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (3.8.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator->-r requirements.txt (line 1)) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator->-r requirements.txt (line 1)) (2.27.1)
# Collecting pybind11>=2.2 (from fasttext-wheel->-r requirements.txt (line 2))
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel->-r requirements.txt (line 2)) (67.7.2)
# Collecting python-levenshtein>=0.12 (from fuzzywuzzy[speedup]->-r requirements.txt (line 3))
#   Downloading python_Levenshtein-0.21.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 8)) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 9)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 9)) (16.0.6)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r requirements.txt (line 10))
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 10)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 10)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 10))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 10))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.1 MB/s eta 0:00:00
# Collecting networkx (from torch->-r requirements.txt (line 9))
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 93.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from networkx->torch->-r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->-r requirements.txt (line 12)) (8.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r requirements.txt (line 10)) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 5)) (1.16.0)
# Collecting Levenshtein==0.21.1 (from python-levenshtein>=0.12->fuzzywuzzy[speedup]->-r requirements.txt (line 3))
#   Downloading Levenshtein-0.21.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 22.0 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.21.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]->-r requirements.txt (line 3))
#   Downloading rapidfuzz-3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 120.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r requirements.txt (line 1)) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 6)) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->-r requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r requirements.txt (line 9)) (1.3.0)
# Installing collected packages: tokenizers, safetensors, fuzzywuzzy, rapidfuzz, pybind11, networkx, Levenshtein, huggingface-hub, fasttext-wheel, deep-translator, transformers, python-levenshtein, simalign
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed Levenshtein-0.21.1 deep-translator-1.11.1 fasttext-wheel-0.9.2 fuzzywuzzy-0.18.0 huggingface-hub-0.15.1 networkx-2.4 pybind11-2.10.4 python-levenshtein-0.21.1 rapidfuzz-3.1.1 safetensors-0.3.1 simalign-0.3 tokenizers-0.13.3 transformers-4.30.2

# %%
import sys
from pathlib import Path
sys.path.append('/content/gdrive/MyDrive/3_year/WSI/lexsubgen/')

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/gdrive/MyDrive/3_year/WSI/lexsubgen/']

# %%
import importlib
import numpy as np
import pandas as pd
from itertools import product, combinations

# %%
from typing import Iterable, Dict, Union
import os

# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Работа с датасетом

# %%
dataset_path = Path('./semeval-2010/semeval_2010_truncated.csv').resolve()
dataset_path
# Out:
# PosixPath('/content/gdrive/MyDrive/3_year/WSI/semeval-2010/semeval_2010_truncated.csv')

# %%
import pandas as pd

# %%
dataset_2010 = pd.read_csv(dataset_path, index_col=0)
dataset_2010.head()
# Out:
#      context_id target_label target_lemma pos_tag  \
# 5285  cheat.v.1      cheat.v        cheat       v
# 5286  cheat.v.2      cheat.v        cheat       v
# 5287  cheat.v.3      cheat.v        cheat       v
# 5288  cheat.v.4      cheat.v        cheat       v
# 5289  cheat.v.5      cheat.v        cheat       v
#
#                                                sentence  target_id
# 5285  [zheng_bing] Good grief ! At first , we , that...         36
# 5286  [zheng_bing] Look , she 's cheating you out of...         16
# 5287  [Tim_Russert] But did n't North Korea develop ...         30
# 5288  [Robert_Gallucci] And the deal would have had ...         21
# 5289  [Tim_Russert] But they broke their word /. [Ro...         10

# %% [markdown]
# # Генерация подстановок

# %%
from lexsubgen.bert_estimator import BertProbEstimator
from lexsubgen.MLM_substitutes import MultilingualSubstituteGenerator
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# 2023-06-27 06:41:52,008 - simalign.simalign - INFO - Initialized the EmbeddingLoader with model: bert-base-multilingual-cased
# INFO:simalign.simalign:Initialized the EmbeddingLoader with model: bert-base-multilingual-cased

# %%
importlib.reload(sys.modules['lexsubgen.wsi_dataset'])
# Out:
# <module 'lexsubgen.wsi_dataset' from '/content/gdrive/MyDrive/3_year/WSI/lexsubgen/wsi_dataset.py'>

# %%
from lexsubgen.wsi_dataset import WSIDataset, simple_collate_fn

# %%
prob_estim_parameters = {
    'temperature': 0.1,
}
gener_parameters = {
    'languages': ['en', 'fr', 'de', 'es', 'ru'],
    'top_k': 30,
    'target_injection': True,
    'source_lang_inj': True,
    'words_only_subst': True,
    'lemmatize': True
}

# %%
prob_estimator = BertProbEstimator(**prob_estim_parameters)
subst_generator = MultilingualSubstituteGenerator(prob_estimator, 'en', **gener_parameters)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from torch.utils.data import DataLoader

# %%
my_dataset = WSIDataset(dataset_2010)
my_dataloader = DataLoader(
    my_dataset,
    batch_size=32,
    collate_fn=simple_collate_fn
)

# %%
subst_folder = Path('./semeval-2010/substitutes').resolve()
subst_folder

filename = 'bert_substitutes.csv'

# %%
from tqdm import tqdm

# %%
for batch in tqdm(my_dataloader):
    res = subst_generator.generate_all_langs(
        batch[:, 0],
        batch[:, 1],
        batch[:, 3],
        batch[:, 2],
    )
    subst_generator.write_substitutes(res,
                                      Path(subst_folder, filename))
# Out:
# 100%|██████████| 6/6 [47:05<00:00, 470.94s/it]

# %%
filename = 'bert_substitutes_transl_inj.csv'
gener_parameters = {
    'languages': ['en', 'fr', 'de', 'es', 'ru'],
    'top_k': 30,
    'target_injection': True,
    'source_lang_inj': False,
    'words_only_subst': True,
    'lemmatize': True
}

# %%
subst_generator = MultilingualSubstituteGenerator(prob_estimator, 'en', **gener_parameters)

# %%
for batch in tqdm(my_dataloader):
    res = subst_generator.generate_all_langs(
        batch[:, 0],
        batch[:, 1],
        batch[:, 3],
        batch[:, 2],
    )
    subst_generator.write_substitutes(res,
                                      Path(subst_folder, filename))
# Out:
# 100%|██████████| 6/6 [37:51<00:00, 378.59s/it]

# %% [markdown]
# # Кластеризация

# %%
subst_folder = Path('./semeval-2010/substitutes').resolve()
subst_folder
# Out:
# PosixPath('/content/gdrive/MyDrive/3_year/WSI/semeval-2010/substitutes')

# %%
subst_dataset = pd.read_csv(Path(subst_folder, 'bert_substitutes.csv'), names=['lang', 'target_lemma', 'context_id', 'substitutes'])
subst_dataset.head()
# Out:
#   lang target_lemma context_id  \
# 0   en         camp   camp.n.1
# 1   en         camp   camp.n.2
# 2   en         camp   camp.n.3
# 3   en         camp   camp.n.4
# 4   en         camp   camp.n.5
#
#                                          substitutes
# 0  camp communiti camp area experi world base reg...
# 1  camp camp base facil site center centr unit fi...
# 2  camp parti organ group side countri agenc gove...
# 3  camp camp home hous field quarter barrack vill...
# 4  camp group categori class posit divis theori q...

# %%
importlib.reload(sys.modules['lexsubgen.clusterizer'])
# Out:
# <module 'lexsubgen.clusterizer' from '/content/gdrive/MyDrive/3_year/WSI/lexsubgen/clusterizer.py'>

# %%
from lexsubgen.clusterizer import SubstituteClusterizer

# %%
clust_folder = Path('./semeval-2010/clusterization').resolve()

# %%
# темплейт для названия файла с результатами кластеризации

fname_tmp = 'bert__{target_inj}__{langs}__{n_subst}__{clusterizer}.json'

# %%
bert_subst_paths = {
    'source_target': Path(subst_folder, 'bert_substitutes.csv'),
    'transl_target': Path(subst_folder, 'bert_substitutes_transl_inj.csv')
}
langs = ['en', 'ru', 'fr',  'de', 'es']
n_substs = [5, 10, 15, 20, 25]
clusterizers = ['kmeans', 'agglomerative']

# %%
from itertools import product, combinations
from tqdm import tqdm

# %%
n = 10
sil_scores = {}
for substitutes_path, clusterizer in tqdm(product(bert_subst_paths, clusterizers)):
    clust = SubstituteClusterizer(
        n_clusters='maxsil=range(2, 7)',
        weighted_tfidf=True,
        use_idf=True,
        clusterizer=clusterizer,
        save_models=False,
    )
    substitutes = pd.read_csv(bert_subst_paths[substitutes_path], names=['lang', 'target_lemma', 'context_id', 'substitutes'])
    clust_res = clust.cluster_all(substitutes, langs=langs, n_subst=n)
    params = {
        'target_inj': substitutes_path,
        'langs': '-'.join(langs),
        'n_subst': n,
        'clusterizer': clusterizer
    }
    filename = fname_tmp.format(**params)
    clust._save_clusterization(clust_res, params, clust_folder, filename)
    sil_score = [v[0] for v in clust_res.values()]
    sil_scores[filename] = np.array(sil_score).mean()

sil_scores
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:00<00:01,  8.47it/s]
#  18%|█▊        | 2/11 [00:00<00:03,  2.71it/s]
#  27%|██▋       | 3/11 [00:00<00:02,  3.47it/s]
#  36%|███▋      | 4/11 [00:00<00:01,  4.34it/s]
#  45%|████▌     | 5/11 [00:01<00:01,  3.05it/s]
#  55%|█████▍    | 6/11 [00:01<00:01,  3.52it/s]
#  64%|██████▎   | 7/11 [00:01<00:00,  4.33it/s]
#  73%|███████▎  | 8/11 [00:01<00:00,  4.97it/s]
#  82%|████████▏ | 9/11 [00:02<00:00,  5.52it/s]
#  91%|█████████ | 10/11 [00:02<00:00,  6.18it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.71it/s]
# 1it [00:02,  2.38s/it]
#   0%|          | 0/11 [00:00<?, ?it/s]
# 100%|██████████| 11/11 [00:00<00:00, 50.80it/s]
# 2it [00:02,  1.13s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.58it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.46it/s]
#  30%|███       | 3/10 [00:00<00:00,  8.09it/s]
#  40%|████      | 4/10 [00:00<00:01,  3.17it/s]
#  50%|█████     | 5/10 [00:01<00:01,  3.62it/s]
#  60%|██████    | 6/10 [00:01<00:00,  4.26it/s]
#  70%|███████   | 7/10 [00:01<00:00,  5.00it/s]
#  80%|████████  | 8/10 [00:01<00:00,  5.48it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  6.22it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.32it/s]
# 3it [00:04,  1.49s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 54.07it/s]
# 4it [00:04,  1.19s/it]
# {'bert__source_target__en-ru-fr-de-es__10__kmeans.json': 0.10151318682509576,
#  'bert__source_target__en-ru-fr-de-es__10__agglomerative.json': 0.09006051582255387,
#  'bert__transl_target__en-ru-fr-de-es__10__kmeans.json': 0.12101911672500203,
#  'bert__transl_target__en-ru-fr-de-es__10__agglomerative.json': 0.10248858968257128}

# %% [markdown]
# ## Разное количество подстановок

# %%
sil_scores = {}
clusterizer = 'kmeans'
langs = langs

for substitutes_path, n in tqdm(product(['source_target'], n_substs)):
    clust = SubstituteClusterizer(
        n_clusters='maxsil=range(2, 7)',
        weighted_tfidf=True,
        use_idf=True,
        clusterizer=clusterizer,
        save_models=False,
    )
    substitutes = pd.read_csv(bert_subst_paths[substitutes_path], names=['lang', 'target_lemma', 'context_id', 'substitutes'])
    clust_res = clust.cluster_all(substitutes, langs=langs, n_subst=n)
    params = {
        'target_inj': substitutes_path,
        'langs': '-'.join(langs),
        'n_subst': n,
        'clusterizer': clusterizer
    }
    filename = fname_tmp.format(**params)
    clust._save_clusterization(clust_res, params, clust_folder, filename)
    sil_score = [v[0] for v in clust_res.values()]
    sil_scores[filename] = np.array(sil_score).mean()

sil_scores
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:00<00:01,  9.96it/s]
#  18%|█▊        | 2/11 [00:00<00:02,  3.80it/s]
#  27%|██▋       | 3/11 [00:00<00:01,  4.45it/s]
#  36%|███▋      | 4/11 [00:00<00:01,  5.69it/s]
#  45%|████▌     | 5/11 [00:00<00:00,  6.13it/s]
#  55%|█████▍    | 6/11 [00:01<00:00,  5.17it/s]
#  64%|██████▎   | 7/11 [00:01<00:00,  4.69it/s]
#  73%|███████▎  | 8/11 [00:02<00:01,  1.91it/s]
#  82%|████████▏ | 9/11 [00:04<00:01,  1.16it/s]
#  91%|█████████ | 10/11 [00:04<00:00,  1.44it/s]
# 100%|██████████| 11/11 [00:05<00:00,  1.97it/s]
# 1it [00:05,  5.64s/it]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:01<00:09,  1.00it/s]
#  18%|█▊        | 2/11 [00:01<00:08,  1.09it/s]
#  27%|██▋       | 3/11 [00:02<00:04,  1.74it/s]
#  36%|███▋      | 4/11 [00:02<00:02,  2.50it/s]
#  45%|████▌     | 5/11 [00:02<00:02,  2.05it/s]
#  55%|█████▍    | 6/11 [00:02<00:01,  2.67it/s]
#  64%|██████▎   | 7/11 [00:03<00:01,  3.43it/s]
#  73%|███████▎  | 8/11 [00:03<00:00,  4.08it/s]
#  82%|████████▏ | 9/11 [00:03<00:00,  4.85it/s]
#  91%|█████████ | 10/11 [00:03<00:00,  5.61it/s]
# 100%|██████████| 11/11 [00:03<00:00,  3.05it/s]
# 2it [00:09,  4.49s/it]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:00<00:01,  8.00it/s]
#  18%|█▊        | 2/11 [00:00<00:04,  2.12it/s]
#  27%|██▋       | 3/11 [00:01<00:02,  3.03it/s]
#  36%|███▋      | 4/11 [00:01<00:02,  2.59it/s]
#  45%|████▌     | 5/11 [00:02<00:02,  2.05it/s]
#  55%|█████▍    | 6/11 [00:02<00:02,  2.29it/s]
#  64%|██████▎   | 7/11 [00:02<00:01,  2.52it/s]
#  73%|███████▎  | 8/11 [00:03<00:01,  2.51it/s]
#  82%|████████▏ | 9/11 [00:03<00:00,  2.38it/s]
#  91%|█████████ | 10/11 [00:04<00:00,  1.97it/s]
# 100%|██████████| 11/11 [00:04<00:00,  2.41it/s]
# 3it [00:13,  4.55s/it]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:00<00:01,  9.15it/s]
#  18%|█▊        | 2/11 [00:00<00:03,  2.42it/s]
#  27%|██▋       | 3/11 [00:01<00:03,  2.50it/s]
#  36%|███▋      | 4/11 [00:01<00:03,  2.20it/s]
#  45%|████▌     | 5/11 [00:02<00:02,  2.38it/s]
#  55%|█████▍    | 6/11 [00:02<00:02,  2.37it/s]
#  64%|██████▎   | 7/11 [00:03<00:01,  2.09it/s]
#  73%|███████▎  | 8/11 [00:03<00:01,  2.03it/s]
#  82%|████████▏ | 9/11 [00:04<00:01,  1.48it/s]
#  91%|█████████ | 10/11 [00:05<00:00,  1.29it/s]
# 100%|██████████| 11/11 [00:06<00:00,  1.61it/s]
# 4it [00:20,  5.47s/it]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:00<00:04,  2.08it/s]
#  18%|█▊        | 2/11 [00:01<00:06,  1.36it/s]
#  27%|██▋       | 3/11 [00:01<00:05,  1.55it/s]
#  36%|███▋      | 4/11 [00:02<00:05,  1.32it/s]
#  45%|████▌     | 5/11 [00:03<00:04,  1.24it/s]
#  55%|█████▍    | 6/11 [00:04<00:03,  1.35it/s]
#  64%|██████▎   | 7/11 [00:04<00:02,  1.50it/s]
#  73%|███████▎  | 8/11 [00:05<00:01,  1.54it/s]
#  82%|████████▏ | 9/11 [00:05<00:01,  1.70it/s]
#  91%|█████████ | 10/11 [00:06<00:00,  1.52it/s]
# 100%|██████████| 11/11 [00:07<00:00,  1.55it/s]
# 5it [00:28,  5.61s/it]
# {'bert__source_target__en-ru-fr-de-es__5__kmeans.json': 0.09793423710873238,
#  'bert__source_target__en-ru-fr-de-es__10__kmeans.json': 0.10170727354415635,
#  'bert__source_target__en-ru-fr-de-es__15__kmeans.json': 0.105022016961798,
#  'bert__source_target__en-ru-fr-de-es__20__kmeans.json': 0.10662075452140819,
#  'bert__source_target__en-ru-fr-de-es__25__kmeans.json': 0.11039357545011459}

# %% [markdown]
# ## Разные комбинации языков

# %%
pairs = list(combinations(langs, 2))[:4]
triples = list(combinations(langs, 3))[:6]
quarters = list(combinations(langs, 4))[:4]

lang_comb = [langs[0:1], *pairs, *triples, *quarters, langs]
lang_comb
# Out:
# [['en'],
#  ('en', 'ru'),
#  ('en', 'fr'),
#  ('en', 'de'),
#  ('en', 'es'),
#  ('en', 'ru', 'fr'),
#  ('en', 'ru', 'de'),
#  ('en', 'ru', 'es'),
#  ('en', 'fr', 'de'),
#  ('en', 'fr', 'es'),
#  ('en', 'de', 'es'),
#  ('en', 'ru', 'fr', 'de'),
#  ('en', 'ru', 'fr', 'es'),
#  ('en', 'ru', 'de', 'es'),
#  ('en', 'fr', 'de', 'es'),
#  ['en', 'ru', 'fr', 'de', 'es']]

# %%
sil_scores = {}
clusterizer = 'kmeans'
n = 10

for substitutes_path, langs in tqdm(product(['source_target'], lang_comb)):
    clust = SubstituteClusterizer(
        n_clusters='maxsil=range(2, 7)',
        weighted_tfidf=True,
        use_idf=True,
        clusterizer=clusterizer,
        save_models=False,
    )
    substitutes = pd.read_csv(bert_subst_paths[substitutes_path], names=['lang', 'target_lemma', 'context_id', 'substitutes'])
    clust_res = clust.cluster_all(substitutes, langs=langs, n_subst=n)
    params = {
        'target_inj': substitutes_path,
        'langs': '-'.join(langs),
        'n_subst': n,
        'clusterizer': clusterizer
    }
    filename = fname_tmp.format(**params)
    clust._save_clusterization(clust_res, params, clust_folder, filename)
    sil_score = [v[0] for v in clust_res.values()]
    sil_scores[filename] = np.array(sil_score).mean()

sil_scores
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:05,  1.63it/s]
#  20%|██        | 2/10 [00:00<00:02,  3.04it/s]
#  30%|███       | 3/10 [00:00<00:01,  4.10it/s]
#  40%|████      | 4/10 [00:01<00:01,  4.99it/s]
#  50%|█████     | 5/10 [00:01<00:00,  5.83it/s]
#  60%|██████    | 6/10 [00:01<00:00,  6.59it/s]
#  70%|███████   | 7/10 [00:01<00:00,  6.88it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.08it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.19it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.53it/s]
# 1it [00:01,  1.85s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.84it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.67it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.61it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.92it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.82it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.77it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.87it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.60it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.36it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.68it/s]
# 2it [00:03,  1.55s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:00,  9.32it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.93it/s]
#  30%|███       | 3/10 [00:00<00:00,  8.80it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.93it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.96it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.59it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.57it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.54it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.80it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.96it/s]
# 3it [00:04,  1.44s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:00,  9.32it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.93it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.61it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.01it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.41it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.69it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.64it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.82it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.35it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.34it/s]
# 4it [00:05,  1.43s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.51it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.46it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.65it/s]
#  40%|████      | 4/10 [00:00<00:00,  8.10it/s]
#  50%|█████     | 5/10 [00:00<00:00,  8.00it/s]
#  60%|██████    | 6/10 [00:00<00:00,  8.10it/s]
#  70%|███████   | 7/10 [00:00<00:00,  8.24it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.89it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.47it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.72it/s]
# 5it [00:07,  1.40s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:00,  9.75it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.76it/s]
#  30%|███       | 3/10 [00:00<00:00,  8.27it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.96it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.79it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.95it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.04it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.38it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.76it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.84it/s]
# 6it [00:08,  1.37s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.83it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.60it/s]
#  30%|███       | 3/10 [00:00<00:00,  8.26it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.86it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.17it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.41it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.43it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.72it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.82it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.71it/s]
# 7it [00:09,  1.36s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.98it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.04it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.58it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.45it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.77it/s]
#  60%|██████    | 6/10 [00:00<00:00,  6.71it/s]
#  70%|███████   | 7/10 [00:01<00:00,  5.66it/s]
#  80%|████████  | 8/10 [00:01<00:00,  4.47it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  3.09it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.90it/s]
# 8it [00:12,  1.76s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:01<00:09,  1.10s/it]
#  20%|██        | 2/10 [00:01<00:06,  1.28it/s]
#  30%|███       | 3/10 [00:03<00:07,  1.09s/it]
#  40%|████      | 4/10 [00:03<00:05,  1.14it/s]
#  50%|█████     | 5/10 [00:04<00:03,  1.47it/s]
#  60%|██████    | 6/10 [00:04<00:02,  1.84it/s]
#  70%|███████   | 7/10 [00:04<00:01,  2.46it/s]
#  80%|████████  | 8/10 [00:04<00:00,  3.13it/s]
#  90%|█████████ | 9/10 [00:04<00:00,  3.86it/s]
# 100%|██████████| 10/10 [00:04<00:00,  2.09it/s]
# 9it [00:17,  2.72s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.49it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.69it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.80it/s]
#  40%|████      | 4/10 [00:00<00:00,  8.12it/s]
#  50%|█████     | 5/10 [00:00<00:00,  8.14it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.76it/s]
#  70%|███████   | 7/10 [00:00<00:00,  8.06it/s]
#  80%|████████  | 8/10 [00:00<00:00,  8.22it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  8.42it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.92it/s]
# 10it [00:18,  2.29s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.69it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.28it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.67it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.92it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.74it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.86it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.51it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.96it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  8.23it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.94it/s]
# 11it [00:19,  1.98s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:00,  9.83it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.19it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.26it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.53it/s]
#  50%|█████     | 5/10 [00:00<00:00,  6.98it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.10it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.17it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.22it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.20it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.34it/s]
# 12it [00:21,  1.81s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.36it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.96it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.95it/s]
#  40%|████      | 4/10 [00:00<00:00,  8.23it/s]
#  50%|█████     | 5/10 [00:00<00:00,  8.18it/s]
#  60%|██████    | 6/10 [00:00<00:00,  8.00it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.61it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.72it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  8.08it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.95it/s]
# 13it [00:22,  1.65s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.57it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.01it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.19it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.42it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.14it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.14it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.41it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.19it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.35it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.29it/s]
# 14it [00:24,  1.58s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  8.78it/s]
#  20%|██        | 2/10 [00:00<00:00,  8.56it/s]
#  30%|███       | 3/10 [00:00<00:00,  8.21it/s]
#  40%|████      | 4/10 [00:00<00:00,  8.24it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.74it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.24it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.29it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.34it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.67it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.65it/s]
# 15it [00:25,  1.51s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:00,  9.50it/s]
#  20%|██        | 2/10 [00:00<00:01,  8.00it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.34it/s]
#  40%|████      | 4/10 [00:00<00:01,  3.37it/s]
#  50%|█████     | 5/10 [00:01<00:01,  3.76it/s]
#  60%|██████    | 6/10 [00:01<00:00,  4.49it/s]
#  70%|███████   | 7/10 [00:01<00:00,  4.34it/s]
#  80%|████████  | 8/10 [00:02<00:00,  2.57it/s]
#  90%|█████████ | 9/10 [00:02<00:00,  2.07it/s]
# 100%|██████████| 10/10 [00:04<00:00,  2.44it/s]
# 16it [00:29,  1.85s/it]
# {'bert__transl_target__en__10__kmeans.json': 0.20587255629979762,
#  'bert__transl_target__en-ru__10__kmeans.json': 0.15787438374000207,
#  'bert__transl_target__en-fr__10__kmeans.json': 0.14946677478848455,
#  'bert__transl_target__en-de__10__kmeans.json': 0.13287539634483472,
#  'bert__transl_target__en-es__10__kmeans.json': 0.16293427386069143,
#  'bert__transl_target__en-ru-fr__10__kmeans.json': 0.1319435910303132,
#  'bert__transl_target__en-ru-de__10__kmeans.json': 0.12748017051669866,
#  'bert__transl_target__en-ru-es__10__kmeans.json': 0.1370100421437237,
#  'bert__transl_target__en-fr-de__10__kmeans.json': 0.1186559660448517,
#  'bert__transl_target__en-fr-es__10__kmeans.json': 0.15647649308488357,
#  'bert__transl_target__en-de-es__10__kmeans.json': 0.12546519181291999,
#  'bert__transl_target__en-ru-fr-de__10__kmeans.json': 0.11580763868827845,
#  'bert__transl_target__en-ru-fr-es__10__kmeans.json': 0.1360097781960023,
#  'bert__transl_target__en-ru-de-es__10__kmeans.json': 0.11968064371438794,
#  'bert__transl_target__en-fr-de-es__10__kmeans.json': 0.12233863322461107,
#  'bert__transl_target__en-ru-fr-de-es__10__kmeans.json': 0.11972365814273453}

# %% [markdown]
# # Подсчет метрик

# %%
importlib.reload(sys.modules['lexsubgen.evaluation'])
# Out:
# <module 'lexsubgen.evaluation' from '/content/gdrive/MyDrive/3_year/WSI/lexsubgen/evaluation.py'>

# %%
from lexsubgen.evaluation import WSIEvaluator

# %%
cluter_results_folder = Path('./semeval-2010/clusterization_results').resolve()
cluter_results_folder
# Out:
# PosixPath('/content/gdrive/MyDrive/3_year/WSI/semeval-2010/clusterization_results')

# %%
def compute_exp_metrics(clust_files: Iterable[str],
                        clust_folder: Union[str, os.PathLike],
                        clust_results_folder: Union[str, os.PathLike],
                        dataset: pd.DataFrame,
                        semeval_data_path='/content/gdrive/MyDrive/3_year/WSI/semeval-2010'):
    exp_names = []
    exp_results = []
    for filename in clust_files:
        eval = WSIEvaluator(dataset=dataset,
                            clust_res_path=Path(clust_folder, filename),
                            semeval_data_path=semeval_data_path)
        metrics = eval.compute_metrics()
        exp_names.append(filename)
        exp_results.append(metrics.loc['mean'])
        metrics.to_csv(Path(clust_results_folder, Path(filename).with_suffix('.csv')))
    return pd.DataFrame(exp_results, index=exp_names)

# %% [markdown]
# target injection

# %%
files = [
    'bert__source_target__en-ru-fr-de-es__10__kmeans.json',
    'bert__source_target__en-ru-fr-de-es__10__agglomerative.json',
    'bert__transl_target__en-ru-fr-de-es__10__kmeans.json',
    'bert__transl_target__en-ru-fr-de-es__10__agglomerative.json'
]
exp1_metrics = compute_exp_metrics(
    files,
    clust_folder,
    cluter_results_folder,
    dataset_2010
)
exp1_metrics
# Out:
#                                                     fscore  precision  recall  \
# bert__source_target__en-ru-fr-de-es__10__kmeans...   42.47      36.73   63.86
# bert__source_target__en-ru-fr-de-es__10__agglom...   52.32      54.58   59.65
# bert__transl_target__en-ru-fr-de-es__10__kmeans...   32.29      26.11   58.58
# bert__transl_target__en-ru-fr-de-es__10__agglom...   48.31      45.58   61.83
#
#                                                     vmeasure  homogenity  \
# bert__source_target__en-ru-fr-de-es__10__kmeans...     28.75       24.69
# bert__source_target__en-ru-fr-de-es__10__agglom...     32.89       36.34
# bert__transl_target__en-ru-fr-de-es__10__kmeans...     27.61       23.56
# bert__transl_target__en-ru-fr-de-es__10__agglom...     29.47       26.83
#
#                                                     completeness  \
# bert__source_target__en-ru-fr-de-es__10__kmeans...         43.49
# bert__source_target__en-ru-fr-de-es__10__agglom...         38.01
# bert__transl_target__en-ru-fr-de-es__10__kmeans...         42.88
# bert__transl_target__en-ru-fr-de-es__10__agglom...         39.95
#
#                                                     (fs * vm) ** 0.5
# bert__source_target__en-ru-fr-de-es__10__kmeans...         32.661893
# bert__source_target__en-ru-fr-de-es__10__agglom...         39.568463
# bert__transl_target__en-ru-fr-de-es__10__kmeans...         29.186564
# bert__transl_target__en-ru-fr-de-es__10__agglom...         35.558408

# %%
exp1_metrics

# %% [markdown]
# n_substs

# %%
files = [
    'bert__source_target__en-ru-fr-de-es__5__kmeans.json',
    'bert__source_target__en-ru-fr-de-es__10__kmeans.json',
    'bert__source_target__en-ru-fr-de-es__15__kmeans.json',
    'bert__source_target__en-ru-fr-de-es__20__kmeans.json',
    'bert__source_target__en-ru-fr-de-es__25__kmeans.json']

exp2_metrics = compute_exp_metrics(
    files,
    clust_folder,
    cluter_results_folder,
    dataset_2010
)
exp2_metrics
# Out:
#                                                     fscore  precision  recall  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....   33.02      25.88   58.51
# bert__source_target__en-ru-fr-de-es__10__kmeans...   44.01      39.22   64.30
# bert__source_target__en-ru-fr-de-es__15__kmeans...   34.72      28.73   57.80
# bert__source_target__en-ru-fr-de-es__20__kmeans...   38.66      35.92   57.52
# bert__source_target__en-ru-fr-de-es__25__kmeans...   39.26      34.80   58.64
#
#                                                     vmeasure  homogenity  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....     23.73       19.94
# bert__source_target__en-ru-fr-de-es__10__kmeans...     32.11       29.96
# bert__source_target__en-ru-fr-de-es__15__kmeans...     27.46       23.80
# bert__source_target__en-ru-fr-de-es__20__kmeans...     23.21       21.55
# bert__source_target__en-ru-fr-de-es__25__kmeans...     26.47       23.72
#
#                                                     completeness  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....         36.16
# bert__source_target__en-ru-fr-de-es__10__kmeans...         47.62
# bert__source_target__en-ru-fr-de-es__15__kmeans...         41.06
# bert__source_target__en-ru-fr-de-es__20__kmeans...         33.26
# bert__source_target__en-ru-fr-de-es__25__kmeans...         38.10
#
#                                                     (fs * vm) ** 0.5
# bert__source_target__en-ru-fr-de-es__5__kmeans....         26.902051
# bert__source_target__en-ru-fr-de-es__10__kmeans...         36.563425
# bert__source_target__en-ru-fr-de-es__15__kmeans...         30.012168
# bert__source_target__en-ru-fr-de-es__20__kmeans...         28.271481
# bert__source_target__en-ru-fr-de-es__25__kmeans...         30.494886

# %%
exp2_metrics.to_csv(Path(cluter_results_folder, 'bert_n_substitutes.csv'))

# %% [markdown]
# Сравнение с fasttext

# %%
truncated_targets = dataset_2010['target_label'].unique()

# %%
files = [
    'fr-es-de-ru-en__5__tf-idf-weighted__kmeans__dummy.csv',
    'fr-es-de-ru-en__10__tf-idf-weighted__kmeans__dummy.csv',
    'fr-es-de-ru-en__15__tf-idf-weighted__kmeans__dummy.csv',
    'fr-es-de-ru-en__20__tf-idf-weighted__kmeans__dummy.csv',
    'fr-es-de-ru-en__25__tf-idf-weighted__kmeans__dummy.csv',
]

exp2_fasttext = []
for file in files:
    exp2 = pd.read_csv(Path(cluter_results_folder, file), index_col=0)
    mean_metrics = exp2.loc[truncated_targets].mean(axis=0)
    exp2_fasttext.append(mean_metrics)
exp2_fasttext = pd.DataFrame(exp2_fasttext, index=files)
exp2_fasttext
# Out:
#                                                     fscore  precision  recall  \
# fr-es-de-ru-en__5__tf-idf-weighted__kmeans__dum...   35.03      29.97   58.85
# fr-es-de-ru-en__10__tf-idf-weighted__kmeans__du...   35.66      30.24   55.63
# fr-es-de-ru-en__15__tf-idf-weighted__kmeans__du...   46.23      43.78   61.90
# fr-es-de-ru-en__20__tf-idf-weighted__kmeans__du...   46.80      41.14   64.00
# fr-es-de-ru-en__25__tf-idf-weighted__kmeans__du...   42.05      40.06   57.93
#
#                                                     vmeasure  homogenity  \
# fr-es-de-ru-en__5__tf-idf-weighted__kmeans__dum...     32.43       28.01
# fr-es-de-ru-en__10__tf-idf-weighted__kmeans__du...     25.54       21.61
# fr-es-de-ru-en__15__tf-idf-weighted__kmeans__du...     30.63       29.93
# fr-es-de-ru-en__20__tf-idf-weighted__kmeans__du...     30.67       26.27
# fr-es-de-ru-en__25__tf-idf-weighted__kmeans__du...     30.53       29.95
#
#                                                     completeness  \
# fr-es-de-ru-en__5__tf-idf-weighted__kmeans__dum...         51.95
# fr-es-de-ru-en__10__tf-idf-weighted__kmeans__du...         38.13
# fr-es-de-ru-en__15__tf-idf-weighted__kmeans__du...         42.26
# fr-es-de-ru-en__20__tf-idf-weighted__kmeans__du...         41.94
# fr-es-de-ru-en__25__tf-idf-weighted__kmeans__du...         41.59
#
#                                                     (fs * vm) ** 0.5
# fr-es-de-ru-en__5__tf-idf-weighted__kmeans__dum...         31.661311
# fr-es-de-ru-en__10__tf-idf-weighted__kmeans__du...         28.681739
# fr-es-de-ru-en__15__tf-idf-weighted__kmeans__du...         35.680309
# fr-es-de-ru-en__20__tf-idf-weighted__kmeans__du...         35.354350
# fr-es-de-ru-en__25__tf-idf-weighted__kmeans__du...         33.279898

# %%
exp2_fasttext.to_csv(Path(cluter_results_folder, 'fasttext_n_substitutes.csv'))

# %% [markdown]
# different lang combintions

# %%
files = [
    'bert__transl_target__en__10__kmeans.json',
    'bert__transl_target__en-ru__10__kmeans.json',
    'bert__transl_target__en-fr__10__kmeans.json',
    'bert__transl_target__en-de__10__kmeans.json',
    'bert__transl_target__en-es__10__kmeans.json',
    'bert__transl_target__en-ru-fr__10__kmeans.json',
    'bert__transl_target__en-ru-de__10__kmeans.json',
    'bert__transl_target__en-ru-es__10__kmeans.json',
    'bert__transl_target__en-fr-de__10__kmeans.json',
    'bert__transl_target__en-fr-es__10__kmeans.json',
    'bert__transl_target__en-de-es__10__kmeans.json',
    'bert__transl_target__en-ru-fr-de__10__kmeans.json',
    'bert__transl_target__en-ru-fr-es__10__kmeans.json',
    'bert__transl_target__en-ru-de-es__10__kmeans.json',
    'bert__transl_target__en-fr-de-es__10__kmeans.json',
    'bert__transl_target__en-ru-fr-de-es__10__kmeans.json'
]
exp3_metrics = compute_exp_metrics(
    files,
    clust_folder,
    cluter_results_folder,
    dataset_2010
)
exp3_metrics
# Out:
#                                                     fscore  precision  recall  \
# bert__transl_target__en__10__kmeans.json             29.84      20.12   64.43
# bert__transl_target__en-ru__10__kmeans.json          30.03      20.80   63.32
# bert__transl_target__en-fr__10__kmeans.json          31.62      22.32   63.98
# bert__transl_target__en-de__10__kmeans.json          27.20      19.13   53.80
# bert__transl_target__en-es__10__kmeans.json          32.15      24.31   60.61
# bert__transl_target__en-ru-fr__10__kmeans.json       32.49      26.30   58.16
# bert__transl_target__en-ru-de__10__kmeans.json       31.73      22.48   63.91
# bert__transl_target__en-ru-es__10__kmeans.json       33.23      24.22   62.47
# bert__transl_target__en-fr-de__10__kmeans.json       34.10      26.31   64.63
# bert__transl_target__en-fr-es__10__kmeans.json       37.70      31.51   63.42
# bert__transl_target__en-de-es__10__kmeans.json       37.00      29.45   65.08
# bert__transl_target__en-ru-fr-de__10__kmeans.json    35.00      26.88   61.14
# bert__transl_target__en-ru-fr-es__10__kmeans.json    33.07      26.23   62.18
# bert__transl_target__en-ru-de-es__10__kmeans.json    29.56      21.88   60.24
# bert__transl_target__en-fr-de-es__10__kmeans.json    37.33      30.28   59.69
# bert__transl_target__en-ru-fr-de-es__10__kmeans...   32.29      26.11   58.58
#
#                                                     vmeasure  homogenity  \
# bert__transl_target__en__10__kmeans.json               36.35       27.62
# bert__transl_target__en-ru__10__kmeans.json            32.18       25.08
# bert__transl_target__en-fr__10__kmeans.json            33.50       25.74
# bert__transl_target__en-de__10__kmeans.json            25.88       20.45
# bert__transl_target__en-es__10__kmeans.json            29.03       23.21
# bert__transl_target__en-ru-fr__10__kmeans.json         27.07       23.63
# bert__transl_target__en-ru-de__10__kmeans.json         31.14       24.83
# bert__transl_target__en-ru-es__10__kmeans.json         30.94       24.43
# bert__transl_target__en-fr-de__10__kmeans.json         32.14       27.17
# bert__transl_target__en-fr-es__10__kmeans.json         31.09       26.89
# bert__transl_target__en-de-es__10__kmeans.json         32.01       26.83
# bert__transl_target__en-ru-fr-de__10__kmeans.json      30.79       25.38
# bert__transl_target__en-ru-fr-es__10__kmeans.json      30.62       25.52
# bert__transl_target__en-ru-de-es__10__kmeans.json      29.52       23.60
# bert__transl_target__en-fr-de-es__10__kmeans.json      28.47       24.90
# bert__transl_target__en-ru-fr-de-es__10__kmeans...     27.61       23.56
#
#                                                     completeness  \
# bert__transl_target__en__10__kmeans.json                   62.53
# bert__transl_target__en-ru__10__kmeans.json                52.16
# bert__transl_target__en-fr__10__kmeans.json                58.06
# bert__transl_target__en-de__10__kmeans.json                40.17
# bert__transl_target__en-es__10__kmeans.json                46.22
# bert__transl_target__en-ru-fr__10__kmeans.json             40.02
# bert__transl_target__en-ru-de__10__kmeans.json             49.03
# bert__transl_target__en-ru-es__10__kmeans.json             52.51
# bert__transl_target__en-fr-de__10__kmeans.json             49.08
# bert__transl_target__en-fr-es__10__kmeans.json             47.87
# bert__transl_target__en-de-es__10__kmeans.json             48.04
# bert__transl_target__en-ru-fr-de__10__kmeans.json          50.43
# bert__transl_target__en-ru-fr-es__10__kmeans.json          49.30
# bert__transl_target__en-ru-de-es__10__kmeans.json          46.03
# bert__transl_target__en-fr-de-es__10__kmeans.json          40.39
# bert__transl_target__en-ru-fr-de-es__10__kmeans...         42.88
#
#                                                     (fs * vm) ** 0.5
# bert__transl_target__en__10__kmeans.json                   32.335335
# bert__transl_target__en-ru__10__kmeans.json                30.332884
# bert__transl_target__en-fr__10__kmeans.json                31.940876
# bert__transl_target__en-de__10__kmeans.json                25.379945
# bert__transl_target__en-es__10__kmeans.json                29.190402
# bert__transl_target__en-ru-fr__10__kmeans.json             29.070906
# bert__transl_target__en-ru-de__10__kmeans.json             30.959766
# bert__transl_target__en-ru-es__10__kmeans.json             31.572790
# bert__transl_target__en-fr-de__10__kmeans.json             32.483132
# bert__transl_target__en-fr-es__10__kmeans.json             32.811013
# bert__transl_target__en-de-es__10__kmeans.json             32.601342
# bert__transl_target__en-ru-fr-de__10__kmeans.json          32.270797
# bert__transl_target__en-ru-fr-es__10__kmeans.json          31.148465
# bert__transl_target__en-ru-de-es__10__kmeans.json          28.784266
# bert__transl_target__en-fr-de-es__10__kmeans.json          31.707352
# bert__transl_target__en-ru-fr-de-es__10__kmeans...         29.186564

# %%
exp3_metrics.to_csv(Path(cluter_results_folder, 'bert_languages.csv'))

# %% [markdown]
# # Визуализация

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
exp2_metrics
# Out:
#                                                     fscore  precision  recall  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....   33.02      25.88   58.51
# bert__source_target__en-ru-fr-de-es__10__kmeans...   44.01      39.22   64.30
# bert__source_target__en-ru-fr-de-es__15__kmeans...   34.72      28.73   57.80
# bert__source_target__en-ru-fr-de-es__20__kmeans...   38.66      35.92   57.52
# bert__source_target__en-ru-fr-de-es__25__kmeans...   39.26      34.80   58.64
#
#                                                     vmeasure  homogenity  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....     23.73       19.94
# bert__source_target__en-ru-fr-de-es__10__kmeans...     32.11       29.96
# bert__source_target__en-ru-fr-de-es__15__kmeans...     27.46       23.80
# bert__source_target__en-ru-fr-de-es__20__kmeans...     23.21       21.55
# bert__source_target__en-ru-fr-de-es__25__kmeans...     26.47       23.72
#
#                                                     completeness  \
# bert__source_target__en-ru-fr-de-es__5__kmeans....         36.16
# bert__source_target__en-ru-fr-de-es__10__kmeans...         47.62
# bert__source_target__en-ru-fr-de-es__15__kmeans...         41.06
# bert__source_target__en-ru-fr-de-es__20__kmeans...         33.26
# bert__source_target__en-ru-fr-de-es__25__kmeans...         38.10
#
#                                                     (fs * vm) ** 0.5
# bert__source_target__en-ru-fr-de-es__5__kmeans....         26.902051
# bert__source_target__en-ru-fr-de-es__10__kmeans...         36.563425
# bert__source_target__en-ru-fr-de-es__15__kmeans...         30.012168
# bert__source_target__en-ru-fr-de-es__20__kmeans...         28.271481
# bert__source_target__en-ru-fr-de-es__25__kmeans...         30.494886

# %%
exp2_metrics = pd.read_csv(Path(cluter_results_folder, 'bert_n_substitutes.csv'))
exp2_metrics[['model', 'target_injection', 'langs', 'n_subst', 'clusterization']] = exp2_metrics['Unnamed: 0'].str.split(pat='__', expand=True)
exp2_metrics['n_langs'] = exp2_metrics['langs'].str.split(pat='-').apply(len)
exp2_metrics.drop(columns=['Unnamed: 0'], inplace=True)

# %%
exp2_metrics
# Out:
#    fscore  precision  recall  vmeasure  homogenity  completeness  \
# 0   33.02      25.88   58.51     23.73       19.94         36.16
# 1   44.01      39.22   64.30     32.11       29.96         47.62
# 2   34.72      28.73   57.80     27.46       23.80         41.06
# 3   38.66      35.92   57.52     23.21       21.55         33.26
# 4   39.26      34.80   58.64     26.47       23.72         38.10
#
#    (fs * vm) ** 0.5 model target_injection           langs n_subst  \
# 0         26.902051  bert    source_target  en-ru-fr-de-es       5
# 1         36.563425  bert    source_target  en-ru-fr-de-es      10
# 2         30.012168  bert    source_target  en-ru-fr-de-es      15
# 3         28.271481  bert    source_target  en-ru-fr-de-es      20
# 4         30.494886  bert    source_target  en-ru-fr-de-es      25
#
#   clusterization  n_langs
# 0    kmeans.json        5
# 1    kmeans.json        5
# 2    kmeans.json        5
# 3    kmeans.json        5
# 4    kmeans.json        5

# %%
exp2_fasttext = pd.read_csv(Path(cluter_results_folder, 'fasttext_n_substitutes.csv'))
exp2_fasttext[['langs', 'n_subst', 'vectorizer', 'clusterization', 'context']] = exp2_fasttext['Unnamed: 0'].str.split(pat='__', expand=True)
exp2_fasttext['n_langs'] = exp2_fasttext['langs'].str.split(pat='-').apply(len)

exp2_fasttext.drop(columns=['Unnamed: 0'], inplace=True)
exp2_fasttext
# Out:
#    fscore  precision  recall  vmeasure  homogenity  completeness  \
# 0   35.03      29.97   58.85     32.43       28.01         51.95
# 1   35.66      30.24   55.63     25.54       21.61         38.13
# 2   46.23      43.78   61.90     30.63       29.93         42.26
# 3   46.80      41.14   64.00     30.67       26.27         41.94
# 4   42.05      40.06   57.93     30.53       29.95         41.59
#
#    (fs * vm) ** 0.5           langs n_subst       vectorizer clusterization  \
# 0         31.661311  fr-es-de-ru-en       5  tf-idf-weighted         kmeans
# 1         28.681739  fr-es-de-ru-en      10  tf-idf-weighted         kmeans
# 2         35.680309  fr-es-de-ru-en      15  tf-idf-weighted         kmeans
# 3         35.354350  fr-es-de-ru-en      20  tf-idf-weighted         kmeans
# 4         33.279898  fr-es-de-ru-en      25  tf-idf-weighted         kmeans
#
#      context  n_langs
# 0  dummy.csv        5
# 1  dummy.csv        5
# 2  dummy.csv        5
# 3  dummy.csv        5
# 4  dummy.csv        5

# %%
fig, ax = plt.subplots(ncols=2, sharey=True, figsize=(12, 5))

barWidth = 0.35

r1 = np.arange(len(exp2_metrics))
r2 = [x + barWidth for x in r1]

b1 = ax[0].bar(r1, exp2_metrics.fscore, width=barWidth, edgecolor="white", linewidth=0.9, color='#9c89b8', label='bert')
ax[0].bar_label(b1, labels=exp2_metrics.fscore.round(1), padding=3, color='#555555')

b1 = ax[1].bar(r1, exp2_metrics.vmeasure, width=barWidth, edgecolor="white", linewidth=0.9, color='#9c89b8', label='bert')
ax[1].bar_label(b1, labels=exp2_metrics.vmeasure.round(1), padding=3, color='#555555')


b2 = ax[0].bar(r2, exp2_fasttext.fscore, width=barWidth, edgecolor="white", linewidth=0.9, color='#f0a6ca', label='fasttext')
ax[0].bar_label(b2, labels=exp2_fasttext.fscore.round(1), padding=3, color='#555555')

b2 = ax[1].bar(r2, exp2_fasttext.vmeasure, width=barWidth, edgecolor="white", linewidth=0.9, color='#f0a6ca', label='fasttext')
ax[1].bar_label(b2, labels=exp2_fasttext.vmeasure.round(1), padding=3, color='#555555')

ax[0].grid(visible=True)
ax[0].set_ylim(top=65)

ax[0].set_xlabel('number of substitutes')
ax[1].set_xlabel('number of substitutes')
ax[0].set_ylabel('fscore')
ax[1].set_ylabel('vmeasure')
fig.suptitle('WSI metrics for different number of substitutes', fontdict={'color': '#555555'})

# Add xticks on the middle of the group bars
ax[0].set_xticks([r + barWidth / 2 for r in range(len(exp2_metrics))], exp2_metrics.n_subst)
ax[0].legend(labelcolor='#555555')
ax[1].set_xticks([r + barWidth / 2 for r in range(len(exp2_metrics))], exp2_metrics.n_subst)
ax[1].legend(labelcolor='#555555')

plt.show()

# %%
exp3 = pd.read_csv(Path(cluter_results_folder, 'bert_languages.csv'))
exp3[['model', 'target_injection', 'langs', 'n_subst', 'clusterization']] = exp3['Unnamed: 0'].str.split(pat='__', expand=True)
exp3['n_langs'] = exp3['langs'].str.split(pat='-').apply(len)
exp3.drop(columns=['Unnamed: 0'], inplace=True)
exp3
# Out:
#     fscore  precision  recall  vmeasure  homogenity  completeness  \
# 0    29.84      20.12   64.43     36.35       27.62         62.53
# 1    30.03      20.80   63.32     32.18       25.08         52.16
# 2    31.62      22.32   63.98     33.50       25.74         58.06
# 3    27.20      19.13   53.80     25.88       20.45         40.17
# 4    32.15      24.31   60.61     29.03       23.21         46.22
# 5    32.49      26.30   58.16     27.07       23.63         40.02
# 6    31.73      22.48   63.91     31.14       24.83         49.03
# 7    33.23      24.22   62.47     30.94       24.43         52.51
# 8    34.10      26.31   64.63     32.14       27.17         49.08
# 9    37.70      31.51   63.42     31.09       26.89         47.87
# 10   37.00      29.45   65.08     32.01       26.83         48.04
# 11   35.00      26.88   61.14     30.79       25.38         50.43
# 12   33.07      26.23   62.18     30.62       25.52         49.30
# 13   29.56      21.88   60.24     29.52       23.60         46.03
# 14   37.33      30.28   59.69     28.47       24.90         40.39
# 15   32.29      26.11   58.58     27.61       23.56         42.88
#
#     (fs * vm) ** 0.5 model target_injection           langs n_subst  \
# 0          32.335335  bert    transl_target              en      10
# 1          30.332884  bert    transl_target           en-ru      10
# 2          31.940876  bert    transl_target           en-fr      10
# 3          25.379945  bert    transl_target           en-de      10
# 4          29.190402  bert    transl_target           en-es      10
# 5          29.070906  bert    transl_target        en-ru-fr      10
# 6          30.959766  bert    transl_target        en-ru-de      10
# 7          31.572790  bert    transl_target        en-ru-es      10
# 8          32.483132  bert    transl_target        en-fr-de      10
# 9          32.811013  bert    transl_target        en-fr-es      10
# 10         32.601342  bert    transl_target        en-de-es      10
# 11         32.270797  bert    transl_target     en-ru-fr-de      10
# 12         31.148465  bert    transl_target     en-ru-fr-es      10
# 13         28.784266  bert    transl_target     en-ru-de-es      10
# 14         31.707352  bert    transl_target     en-fr-de-es      10
# 15         29.186564  bert    transl_target  en-ru-fr-de-es      10
#
#    clusterization  n_langs
# 0     kmeans.json        1
# 1     kmeans.json        2
# 2     kmeans.json        2
# 3     kmeans.json        2
# 4     kmeans.json        2
# 5     kmeans.json        3
# 6     kmeans.json        3
# 7     kmeans.json        3
# 8     kmeans.json        3
# 9     kmeans.json        3
# 10    kmeans.json        3
# 11    kmeans.json        4
# 12    kmeans.json        4
# 13    kmeans.json        4
# 14    kmeans.json        4
# 15    kmeans.json        5

# %%
max_metrics_rows = exp3.groupby(by='n_langs').idxmax()
max_metrics_rows
# Out:
#          fscore  precision  recall  vmeasure  homogenity  completeness  \
# n_langs
# 1             0          0       0         0           0             0
# 2             4          4       2         2           2             2
# 3             9          9      10         8           8             7
# 4            14         14      12        11          12            11
# 5            15         15      15        15          15            15
#
#          (fs * vm) ** 0.5
# n_langs
# 1                       0
# 2                       2
# 3                       9
# 4                      11
# 5                      15

# %%
fscore_max_vals = exp3.loc[max_metrics_rows.fscore]['fscore'].values
fscore_max_langs = exp3.loc[max_metrics_rows.fscore]['langs'].values
vmeasure_max_vals = exp3.loc[max_metrics_rows.vmeasure]['vmeasure'].values
vmeasure_max_langs = exp3.loc[max_metrics_rows.vmeasure]['langs'].values

# %%
from collections import defaultdict

# %%
fscore = exp3.groupby(['n_langs'])['fscore'].value_counts()

other_fscore = []
for i, val in fscore.index:
    if fscore_max_vals[i - 1] != val:
        other_fscore.append((i,val))
other_fscore = list(zip(*other_fscore))

# %%
vmeasure = exp3.groupby(['n_langs'])['vmeasure'].value_counts()

other_vmeasure = []
for i, val in vmeasure.index:
    if vmeasure_max_vals[i - 1] != val:
        other_vmeasure.append((i,val))
other_vmeasure = list(zip(*other_vmeasure))

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.set_xticks(max_metrics_rows.index)
ax.set_ylim(top=65)
ax.set_xlim(left=0.7, right=5.7)

ax.scatter(other_fscore[0], other_fscore[1], marker="*", color='#9c89b8')
ax.plot(max_metrics_rows.index, fscore_max_vals, marker='o', markersize=8, color='#9c89b8', label='fscore', linewidth=2.5)
for i, txt in enumerate(fscore_max_langs):
    if i < 2:
        b1, b2 = -6, -8
    else:
        b1, b2 = +6, +8
    ax.annotate(txt, (max_metrics_rows.index[i] + 0.1, fscore_max_vals[i] + b2), color='#555555')
    ax.annotate(fscore_max_vals[i].round(1), (max_metrics_rows.index[i] + 0.1, fscore_max_vals[i] + b1), color='#555555')

ax.scatter(other_vmeasure[0], other_vmeasure[1], marker='*', color='#f0a6ca')
ax.plot(max_metrics_rows.index, vmeasure_max_vals, marker='o', markersize=8, color='#f0a6ca', label='vmeasure', linewidth=2.5)
for i, txt in enumerate(vmeasure_max_langs):
    if i < 2:
        b1, b2 = +4, +6
    else:
        b1, b2 = -4, -6
    ax.annotate(txt, (max_metrics_rows.index[i] + 0.1, vmeasure_max_vals[i] + b2), color='#555555')
    ax.annotate(vmeasure_max_vals[i].round(1), (max_metrics_rows.index[i] + 0.1, vmeasure_max_vals[i] +b1), color='#555555')

ax.set_xlabel('number of languages')
ax.set_ylabel('score')
ax.legend(labelcolor='#555555', loc='lower left')
ax.set_title('Best language combinations for substitutes', fontdict={'color': '#555555'})
# Out:
# Text(0.5, 1.0, 'Best language combinations for substitutes')
